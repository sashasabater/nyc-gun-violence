# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
nypd = pd.read_csv('nypd.csv')
nypd['Date'] = pd.to_datetime(nypd['OCCUR_DATE'])
nypd = nypd.drop('OCCUR_DATE', axis=1)

# %%
nypd[(nypd['BORO'] == 'MANHATTAN') & (nypd['STATISTICAL_MURDER_FLAG']==True)]
# Out:
#        INCIDENT_KEY OCCUR_TIME       BORO  PRECINCT  JURISDICTION_CODE  \
# 33        203348698   21:50:00  MANHATTAN        25                0.0
# 91        197660693   05:21:00  MANHATTAN        23                2.0
# 116       203980164   14:43:00  MANHATTAN        32                0.0
# 163       198266990   02:21:00  MANHATTAN        30                0.0
# 168       199728579   02:45:00  MANHATTAN         9                2.0
# ...             ...        ...        ...       ...                ...
# 23367     209468786   02:30:00  MANHATTAN        25                0.0
# 23368     209809344   19:05:00  MANHATTAN        23                2.0
# 23369     214948389   18:15:00  MANHATTAN        28                0.0
# 23469     211964520   19:48:00  MANHATTAN        23                2.0
# 23473     214948387   02:42:00  MANHATTAN        28                0.0
#
#                    LOCATION_DESC  STATISTICAL_MURDER_FLAG PERP_AGE_GROUP  \
# ...

# %%
nypd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23568 entries, 0 to 23567
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   INCIDENT_KEY             23568 non-null  int64
#  1   OCCUR_TIME               23568 non-null  object
#  2   BORO                     23568 non-null  object
#  3   PRECINCT                 23568 non-null  int64
#  4   JURISDICTION_CODE        23566 non-null  float64
#  5   LOCATION_DESC            9987 non-null   object
#  6   STATISTICAL_MURDER_FLAG  23568 non-null  bool
#  7   PERP_AGE_GROUP           15109 non-null  object
#  8   PERP_SEX                 15143 non-null  object
#  9   PERP_RACE                15143 non-null  object
#  10  VIC_AGE_GROUP            23568 non-null  object
#  11  VIC_SEX                  23568 non-null  object
#  12  VIC_RACE                 23568 non-null  object
#  13  X_COORD_CD               23568 non-null  object
# ...
